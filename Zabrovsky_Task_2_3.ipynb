# %% [markdown]
# # Vladislav Zabrovsky, K-23
# # Task 2.2
# ### Birthday - 29
# ##### a = 2
# ##### b = 9
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-12%20150550.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-12%20150550.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
n = 10000
x = np.linspace(-2, 2, 400)
y = np.linspace(-2, 2, 400)
X, Y = np.meshgrid(x, y)
    
Z = 2 * X**2 + 9 * (Y - np.sqrt(np.abs(X)))**2 - 1
square = []
for i in range(10):
    x_val = np.random.uniform(-2,2,n)
    y_val = np.random.uniform(-2,2,n)
    points = list(zip(x_val,y_val))
    count = 0
    for x,y in points:
    
        if 2 * x**2 + 9 * (y - np.sqrt(np.abs(x)))**2 - 1 <= 5:
            count += 1
            if i == 9:
                plt.plot(x,y,marker='o', color='red', markersize=2)
        else:
            if i == 9:
                plt.plot(x,y,marker='o', color='green', markersize=2)
    square.append(count/n * 16)
plt.contour(X, Y, Z, levels=[5], colors='b')
plt.title('Plot')
plt.text(2.5, 0, "The plot shows dots for the last 10 iteration", fontsize=12)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

print(f"Square of heart = {np.mean(square)}")
print(f"Squares per iteration - {square}")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Square of heart = 4.42
# Squares per iteration - [4.4032, 4.4528, 4.3824, 4.3968, 4.5376, 4.4, 4.328, 4.4624, 4.4704, 4.3664]

# %% [markdown]
# # Task 2.1
# ## My number in 1st group - 3
#
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-12%20150752.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-12%20150752.png)
# The graph is located inside the cube : x = [0,16], y = [-8,8] in my case

# %%
N = 10000
T = 100

squares = []

for _ in range(T):
    count = 0

    for _ in range(N):
        x_value = np.random.uniform(0, 16)
        y_value = np.random.uniform(-8, 8)

        if (-x_value / 3 <= y_value <= x_value / 3) and (8 * x_value <= x_value**2 + y_value**2 <= 16 * x_value):
            count += 1

    square_estimate = count / N * 16 * 16
    squares.append(square_estimate)

print(f"Estimated area of plot: {np.mean(squares)}")
# Out:
# Estimated area of plot: 59.85843199999999

# %% [markdown]
# # 3 Task

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-12%20152402.png](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-10-12%20152402.png)

# %%
from matplotlib import cm
from matplotlib.ticker import LinearLocator
 

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')  


X = np.linspace(-10, 10, 1000)
Y = np.linspace(-10, 10, 1000)
X, Y = np.meshgrid(X, Y)

Z = 5*X*X + 3*Y*Y - np.cos(X/2)*np.cos(Y/(np.sqrt(3))) + 1



surf = ax.plot_surface(X, Y, Z, cmap=cm.viridis, linewidth=0)


ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter('{x:.02f}')


fig.colorbar(surf, shrink=0.6, aspect=10)

plt.show()
print(f"Function minimum  = {np.min(Z)}")
print(f"Function maximum  = {np.max(Z)}")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Function minimum  = 0.0008308272090252755
# Function maximum  = 800.7523914474617
